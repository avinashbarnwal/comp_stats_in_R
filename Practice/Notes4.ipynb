# %% [markdown]
# ## T test

# %%
daily.intake = c(5260,5470,5640,6180,6390,6515,6805,7515,7515,8230,8770)

# %%
res = t.test(daily.intake,mu=7725)

# %% [markdown]
# ## Wilcoxon Signed Rank Test

# %%
x = c(-7,4,-18,-17,3,5,-1,-10,-11,2)
wilcox.test(x)
# Out:
# 	Wilcoxon signed rank test
#
# data:  x
# V = 14, p-value = 0.1934
# alternative hypothesis: true location is not equal to 0

# %% [markdown]
# ## Applied Normal for large Sample

# %% [markdown]
# ## Two Sample t-test

# %%
ret = read.table("http://www.ams.sunysb.edu/~pfkuan/Teaching/AMS597/Data/d_logret_6stocks.txt",header=T)
attach(ret)

# %%
res3 = t.test(Pfizer,Intel)
t.test(Pfizer,Intel,var.equal=T)
# Out:
# 	Two Sample t-test
#
# data:  Pfizer and Intel
# t = 0.21707, df = 126, p-value = 0.8285
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.01578133  0.01966986
# sample estimates:
#    mean of x    mean of y
# -0.004041315 -0.005985579

# %%
var.test(Pfizer,Intel)
# Out:
# 	F test to compare two variances
#
# data:  Pfizer and Intel
# F = 0.11577, num df = 63, denom df = 63, p-value = 3.703e-15
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  0.07033263 0.19055829
# sample estimates:
# ratio of variances
#           0.115769

# %%
wilcox.test(Pfizer,Intel)
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  Pfizer and Intel
# W = 2019, p-value = 0.892
# alternative hypothesis: true location shift is not equal to 0

# %% [markdown]
# ## Simple Regression

# %%
logret = read.table("http://www.ams.sunysb.edu/~pfkuan/Teaching/AMS597/Data/d_logret_6stocks.txt",header=T)
attach(logret)
# Out:
# The following objects are masked from ret:
#
#     AmerExp, Citigroup, Date, Exxon, GenMotor, Intel, Pfizer

# %%
fit1 = lm(Pfizer~Intel)
summary(fit1)
# Out:
# Call:
# lm(formula = Pfizer ~ Intel)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.055920 -0.013845  0.000851  0.017246  0.045693
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.003903   0.002913  -1.340    0.185
# Intel        0.023078   0.043112   0.535    0.594
#
# Residual standard error: 0.02321 on 62 degrees of freedom
# Multiple R-squared:  0.0046,	Adjusted R-squared:  -0.01145
# F-statistic: 0.2865 on 1 and 62 DF,  p-value: 0.5944

# %%
plot(fitted(fit1),resid(fit1))
# Out:
# plot without title

# %% [markdown]
# ## Prediction and Confidence bands

# %% [markdown]
# #### Narrow - Confidence Limits

# %% [markdown]
# #### Wide - Future Limits

# %%
predict(fit1,interval='confidence')
predict(fit1,interval='prediction')
# Out:
#    fit           lwr          upr
# 1  -0.0027497170 -0.010293379 0.004793945
# 2  -0.0098023371 -0.032083930 0.012479256
# 3  -0.0031059136 -0.009876806 0.003664979
# 4  -0.0055774973 -0.013735418 0.002580423
# 5  -0.0062686160 -0.016408775 0.003871543
# 6  -0.0018210192 -0.011939729 0.008297690
# 7  -0.0064923877 -0.017328516 0.004343740
# 8  -0.0047271105 -0.011067616 0.001613395
# 7  -0.0064923877 -0.05414323 0.04115846
# 8  -0.0047271105 -0.05156068 0.04210646
# 9  -0.0022878538 -0.04950756 0.04493185
# 10 -0.0052477127 -0.05222771 0.04173228
# 11 -0.0031038796 -0.04999822 0.04379046
# 12 -0.0037146614 -0.05049406 0.04306474
# 13 -0.0045385026 -0.05133884 0.04226184
# 14 -0.0070402547 -0.05512602 0.04104551
# 15 -0.0021212967 -0.04943126 0.04518866
# 16 -0.0009819628 -0.04912077 0.04715684
# 17 -0.0042821637 -0.05105431 0.04248998
# 18 -0.0028213677 -0.04980624 0.04416351
# 19 -0.0059497454 -0.05325317 0.04135368
# 20 -0.0032712130 -0.05012305 0.04358063
# 21 -0.0045135463 -0.05131028 0.04228319
# 22 -0.0042470549 -0.05101686 0.04252275
# 23 -0.0080473355 -0.05714537 0.04105070
# 24 -0.0036202090 -0.05041014 0.04316972
# 25 -0.0050925670 -0.05202055 0.04183542
# 26 -0.0057292852 -0.05291570 0.04145713
# 27 -0.0017022410 -0.04927452 0.04587003
# 28 -0.0020107797 -0.04938504 0.04536348
# 29 -0.0068456348 -0.05476735 0.04107608
# 30 -0.0038440493 -0.05061335 0.04292525
# ⋮  ⋮             ⋮           ⋮
# 35 -0.003908097  -0.05067424 0.04285805
# 36 -0.002107038  -0.04942510 0.04521102
# 37 -0.002508480  -0.04962100 0.04460404
# 38 -0.004285977  -0.05105840 0.04248644
# 39 -0.002095682  -0.04942023 0.04522887
# 40 -0.003721756  -0.05050048 0.04305696
# 41 -0.004358264  -0.05113674 0.04242021
# 42 -0.004393301  -0.05117527 0.04238866
# 43 -0.004334253  -0.05111054 0.04244204
# 44 -0.004612913  -0.05142510 0.04219927
# 45 -0.004458634  -0.05124809 0.04233082
# 46 -0.002846400  -0.04982230 0.04412950
# 47 -0.004244439  -0.05101409 0.04252521
# 48 -0.005143863  -0.05208826 0.04180053
# 49 -0.005247485  -0.05222740 0.04173243
# 50 -0.004498855  -0.05129355 0.04229584
# 51 -0.002858866  -0.04983037 0.04411264
# 52 -0.003830321  -0.05060045 0.04293981
# 53 -0.003463775  -0.05027698 0.04334943
# 54 -0.004315399  -0.05109010 0.04245930
# 55 -0.003199934  -0.05006886 0.04366900
# 56 -0.004224651  -0.05099316 0.04254386
# 57 -0.003781955  -0.05055548 0.04299157
# 58 -0.002499969  -0.04961636 0.04461642
# 59 -0.004257292  -0.05102774 0.04251316
# 60 -0.003481952  -0.05029208 0.04332817
# 61 -0.004413948  -0.05119814 0.04237025
# 62 -0.004326508  -0.05110213 0.04244911
# 63 -0.004383622  -0.05116459 0.04239734
# 64 -0.002548278  -0.04964297 0.04454642

# %% [markdown]
# ## Correlation

# %%
cor(Pfizer,Intel)
cor.test(Pfizer,Intel)
# Out:
# [1] 0.06782663
# 	Pearson's product-moment correlation
#
# data:  Pfizer and Intel
# t = 0.5353, df = 62, p-value = 0.5944
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1810004  0.3084926
# sample estimates:
#        cor
# 0.06782663
